# %% [markdown]
# # Machine learning model to accurately classify whether or not the patients in the dataset have diabetes or not

# %%
# linear algebra
import numpy as np 

# data processing
import pandas as pd 

# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
import  missingno as ms

# Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV

from scipy import stats 

# Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Visualization

# %%
data = pd.read_csv('Pima_Indian_diabetes.csv')
df = data.copy()
df.rename(columns={'DiabetesPedigreeFunction': 'DPF'}, inplace=True)
df.head()
# Out:
#    Pregnancies    Glucose  BloodPressure  SkinThickness    Insulin       BMI  \
# 0     6.000000 148.000000      72.000000      35.000000   0.000000 33.600000
# 1     1.000000  85.000000      66.000000      29.000000   0.000000 26.600000
# 2     8.000000 183.000000      64.000000       0.000000   0.000000 23.300000
# 3     1.000000  89.000000      66.000000      23.000000  94.000000 19.179925
# 4     0.000000 137.000000      40.000000      35.000000 168.000000 43.100000
#
#        DPF       Age  Outcome
# 0 0.627000 50.000000        1
# 1 0.351000 31.000000        0
# 2 0.672000 32.000000        1
# 3 0.167000 21.000000        0
# 4 2.288000 33.000000        1

# %%
print(df.shape)
df.describe()
# Out:
# (768, 9)
#        Pregnancies    Glucose  BloodPressure  SkinThickness    Insulin  \
# count   742.000000 752.000000     768.000000     746.000000 768.000000
# mean      3.866601 119.966097      68.886078      20.309879  79.799479
# std       3.479971  32.367659      19.427448      15.974523 115.244002
# min      -5.412815   0.000000      -3.496455     -11.945520   0.000000
# 25%       1.000000  99.000000      62.000000       0.000000   0.000000
# 50%       3.000000 116.000000      72.000000      23.000000  30.500000
# 75%       6.000000 140.000000      80.000000      32.000000 127.250000
# max      17.000000 199.000000     122.000000      99.000000 846.000000
#
#              BMI        DPF        Age    Outcome
# count 757.000000 768.000000 749.000000 768.000000
# mean   31.711151   0.471876  33.761336   0.348958
# std     8.544789   0.331329  12.297409   0.476951
# min   -16.288921   0.078000  21.000000   0.000000
# 25%    27.100000   0.243750  24.000000   0.000000
# 50%    32.000000   0.372500  29.000000   0.000000
# 75%    36.500000   0.626250  41.000000   1.000000
# max    67.100000   2.420000  81.000000   1.000000

# %% [markdown]
# #### We can clearly see that Pregnancies, BloodPressure, SkinThickness and BMI have negative values; Glucose and Insulin have zero values, which are biologically implausible

# %%
df.hist(figsize=(9, 9))
plt.show()

# %% [markdown]
# #### This histogram analysis shows us that BMI, BloodPRessure and Glucose follow Gaussian Distribution which can help us in imputing values in the dataset which we will look at subsequently.
# #### We can also see that Insulin and SkinThickness have a lot of zeros which need to be taken care of

# %%
ms.matrix(df)
plt.show()

# %% [markdown]
# #### This is a graph representing the null values in our dataset, where white lines indicate the null values at that particular index

# %%
df_test_1 = df.copy()
df_test_1.loc[df_test_1['Insulin'] <= 0, 'Insulin'] = np.nan
df_test_1.loc[df_test_1['SkinThickness'] <= 0, 'SkinThickness'] = np.nan
ms.matrix(df_test_1)
plt.show()

# %% [markdown]
# #### After making the zero values of SkinThickness and Insulin as null, we can see that Insulin and SkinThickness has a high percentage of null values

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row0_col1 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row0_col2 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row0_col3 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row0_col7 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row0_col8 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row1_col0 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row1_col2 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row1_col3 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row1_col4 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row1_col5 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row1_col6 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row1_col7 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row1_col8 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row2_col0 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row2_col1 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row2_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row2_col4 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row2_col5 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row2_col6 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row2_col7 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row3_col2 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row3_col4 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row3_col5 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row3_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row3_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row3_col8 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row4_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row4_col2 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row4_col3 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row4_col5 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row4_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row4_col7 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row4_col8 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row5_col0 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row5_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row5_col2 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row5_col3 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row5_col4 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row5_col6 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row5_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row5_col8 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row6_col0 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row6_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row6_col3 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row6_col4 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_a2b1130a_d7d0_11e9_9ecd_10f0057c9f98row6_col5 {
#             background-color:  #6c8ff1;
#             color:  #000000;

# %% [markdown]
# #### An interesting thing to note here is that SkinThickness and BMI, and Glucose and Insulin have a moderate correlation with each other respectively
# #### Also the correlation between SkinThickness and Outcome is low

# %%
# fig, axs = plt.subplots(2, figsize=(10,10))
# axs[0].scatter(df['SkinThickness'], df['BMI'])
# # axs[0].set_title('SkinThickness')
# axs[0].set_ylabel('SkinThickness')
# axs[0].set_xlabel('BMI') 
# axs[1].scatter(df['Insulin'], df['Glucose'])
# # axs[1].set_title('Insulin')
# axs[1].set_ylabel('Glucose')
# axs[1].set_xlabel('Insulin')

# %% [markdown]
# # Outlier Detection

# %%
df = data.copy()
df.rename(columns={'DiabetesPedigreeFunction': 'DPF'}, inplace=True)
df.loc[df['Pregnancies'] < 0, 'Pregnancies'] = np.nan
df.loc[df['Glucose'] <= 0, 'Glucose'] = np.nan
df.loc[df['Insulin'] <= 0, 'Insulin'] = np.nan
df.loc[df['BMI'] <= 7, 'BMI'] = np.nan # least possible known BMI is 7
df.loc[df['BloodPressure'] <= 0, 'BloodPressure'] = np.nan
df.loc[df['Age'] <= 0, 'Age'] = np.nan
df.loc[df['SkinThickness'] <= 0, 'SkinThickness'] = np.nan
df.isnull().sum()
# Out:
# Pregnancies       29
# Glucose           21
# BloodPressure     35
# SkinThickness    242
# Insulin          374
# BMI               27
# DPF                0
# Age               19
# Outcome            0
# dtype: int64

# %% [markdown]
# #### Here we are handling biologically implausible data by making them null

# %%
zscore = 3
print(df.isnull().sum())
df.loc[np.abs(stats.zscore(df['BMI'])) > zscore, 'BMI'] = np.nan
df.loc[np.abs(stats.zscore(df['Glucose'])) > zscore, 'Glucose'] = np.nan
df.loc[np.abs(stats.zscore(df['Insulin'])) > zscore, 'Insulin'] = np.nan
df.loc[np.abs(stats.zscore(df['DPF'])) > zscore, 'DPF'] = np.nan
df.loc[np.abs(stats.zscore(df['BloodPressure'])) > zscore, 'BloodPressure'] = np.nan
df.loc[np.abs(stats.zscore(df['Age'])) > zscore, 'Age'] = np.nan
df.loc[np.abs(stats.zscore(df['Pregnancies'])) > zscore, 'Pregnancies'] = np.nan
df.loc[np.abs(stats.zscore(df['SkinThickness'])) > zscore, 'SkinThickness'] = np.nan
print(df.isnull().sum())
df.describe()
# Out:
# Pregnancies       29
# Glucose           21
# BloodPressure     35
# SkinThickness    242
# Insulin          374
# BMI               27
# DPF                0
# Age               19
# Outcome            0
# dtype: int64
# Pregnancies       29
# Glucose           21
# BloodPressure     35
# SkinThickness    242
# Insulin          374
# BMI               27
# DPF               11
# Age               19
# Outcome            0
# dtype: int64
#        Pregnancies    Glucose  BloodPressure  SkinThickness    Insulin  \
# count   739.000000 747.000000     733.000000     526.000000 394.000000
# mean      3.902135 120.769083      72.185074      28.874152 155.548223
# std       3.441810  30.944811      12.502210      10.598375 118.775855
# min       0.000000  42.974768      15.372031       7.000000  14.000000
# 25%       1.000000  99.000000      64.000000      21.000000  76.250000
# 50%       3.000000 117.000000      72.000000      29.000000 125.000000
# 75%       6.000000 140.000000      80.000000      36.000000 190.000000
# max      17.000000 199.000000     122.000000      99.000000 846.000000
#
#              BMI        DPF        Age    Outcome
# count 741.000000 757.000000 749.000000 768.000000
# mean   32.430286   0.450923  33.761336   0.348958
# std     7.029733   0.281586  12.297409   0.476951
# min     9.639841   0.078000  21.000000   0.000000
# 25%    27.500000   0.240000  24.000000   0.000000
# 50%    32.400000   0.366000  29.000000   0.000000
# 75%    36.600000   0.607000  41.000000   1.000000
# max    67.100000   1.461000  81.000000   1.000000

# %% [markdown]
# #### zscore function computes the relative Z-score of the input data, relative to the sample mean and standard deviation which is similar to mahalanobis distance. We have used an absolute threshold of 3 to detect outliers

# %% [markdown]
# # Missing Data Handling

# %%
def fill_null_with_mean_std(df,feature):
    mean = df[feature].mean()
    std = df[feature].std()
    is_null = df[feature].isnull().sum()
    rand_feature = np.random.randint(mean - std, mean + std, size = is_null)
    age_feature = df[feature].copy()
    age_feature[np.isnan(age_feature)] = rand_feature
    df[feature] = age_feature
    return df

def fill_null_with_mode(df,feature):
    mode = df[feature].value_counts().idxmax()
    df[feature].fillna(mode, inplace = True)
    return df

# %%
gaussian_features = ['Glucose', 'BMI', 'BloodPressure']
df = fill_null_with_mean_std(df,'Glucose')
df = fill_null_with_mean_std(df,'BMI')
df = fill_null_with_mean_std(df,'BloodPressure')
df = fill_null_with_mode(df,'DPF')
df = fill_null_with_mode(df,'Pregnancies')
df = fill_null_with_mode(df,'Age')
df.describe()
# Out:
#        Pregnancies    Glucose  BloodPressure  SkinThickness    Insulin  \
# count   768.000000 768.000000     768.000000     526.000000 394.000000
# mean      3.792549 120.667325      72.099817      28.874152 155.548223
# std       3.421196  30.668891      12.325967      10.598375 118.775855
# min       0.000000  42.974768      15.372031       7.000000  14.000000
# 25%       1.000000  99.000000      64.000000      21.000000  76.250000
# 50%       3.000000 116.500000      72.000000      29.000000 125.000000
# 75%       6.000000 140.000000      80.000000      36.000000 190.000000
# max      17.000000 199.000000     122.000000      99.000000 846.000000
#
#              BMI        DPF        Age    Outcome
# count 768.000000 768.000000 768.000000 768.000000
# mean   32.415159   0.448103  33.470365   0.348958
# std     6.953141   0.280539  12.280961   0.476951
# min     9.639841   0.078000  21.000000   0.000000
# 25%    27.500000   0.243750  24.000000   0.000000
# 50%    32.400000   0.361500  29.000000   0.000000
# 75%    36.500000   0.602000  41.000000   1.000000
# max    67.100000   1.461000  81.000000   1.000000

# %% [markdown]
# #### For the features Glucose, BMI, and BloodPressure we fill the missing values by taking random values between mean and standard deviation. This can be done because as established earlier these features follow Gaussian Distribution
# #### DPF, Pregnancies and Age are have skewed distribution, so substituting null values with mode makes for a better imputation

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row0_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row0_col2 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row0_col3 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row0_col4 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row0_col7 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row0_col8 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row1_col0 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row1_col2 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row1_col3 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row1_col4 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row1_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row1_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row1_col7 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row1_col8 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row2_col0 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row2_col1 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row2_col3 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row2_col4 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row2_col5 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row2_col6 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row2_col7 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row3_col0 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row3_col1 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row3_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row3_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row3_col5 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row3_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row3_col7 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row3_col8 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row4_col0 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row4_col1 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row4_col2 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row4_col3 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row4_col5 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row4_col6 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row4_col7 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row4_col8 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row5_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row5_col2 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row5_col3 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row5_col4 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row5_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row5_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row5_col8 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row6_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row6_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row6_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130b_d7d0_11e9_9ecd_10f0057c9f98row6_col5 {
#             background-color:  #6384eb;
#             color:  #000000;

# %%
# Linear regression for SkinThickness and BMI
train_df = df[df['SkinThickness'].notnull()]
x = train_df[['BMI']].values
y = train_df.SkinThickness.values
lr = LinearRegression()
lr.fit(x,y)
x_test = df[np.isnan(df['SkinThickness'])][['BMI']].values 
y_pred = lr.predict(x_test)
SkinThickness_feature = df['SkinThickness'].copy()
SkinThickness_feature[np.isnan(SkinThickness_feature)] = y_pred
df['SkinThickness'] = SkinThickness_feature

# %% [markdown]
# #### We can see that after imputing missing data for all the other features, the correlation between SkinThickness and BMI if 0.6 which is considered high correlation

# %%
plt.scatter(df['SkinThickness'], df['BMI'])
plt.ylabel('SkinThickness')
plt.xlabel('BMI')
# Out:
# Text(0.5, 0, 'BMI')

# %% [markdown]
# #### Due to high correlation and linearity, imputation of SkinThickness can be performed using Linear Regression with BMI as the feature

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row0_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row0_col2 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row0_col4 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row0_col7 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row0_col8 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row1_col0 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row1_col2 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row1_col3 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row1_col4 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row1_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row1_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row1_col7 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row1_col8 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row2_col0 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row2_col1 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row2_col4 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row2_col5 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row2_col6 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row2_col7 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row3_col0 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row3_col1 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row3_col2 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row3_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row3_col5 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row3_col6 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row3_col7 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row3_col8 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row4_col0 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row4_col1 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row4_col2 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row4_col3 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row4_col5 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row4_col6 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row4_col7 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row4_col8 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row5_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row5_col2 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row5_col3 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row5_col4 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row5_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row5_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row5_col8 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row6_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row6_col3 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row6_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130c_d7d0_11e9_9ecd_10f0057c9f98row6_col5 {
#             background-color:  #6384eb;
#             color:  #000000;

# %%
# Linear regression for Insulin and Glucose
train_df = df[df['Insulin'].notnull()]
x = train_df[['Glucose']].values
y = train_df.Insulin.values
lr = LinearRegression()
lr.fit(x,y)
x_test = df[np.isnan(df['Insulin'])][['Glucose']].values
y_pred = lr.predict(x_test)
Insulin_feature = df['Insulin'].copy()
Insulin_feature[np.isnan(Insulin_feature)] = y_pred
df['Insulin'] = Insulin_feature

# %% [markdown]
# #### We can see that after imputing missing data for all the other features, the correlation between Insulin and Glucose if 0.56 which is considered high correlation

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row0_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row0_col2 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row0_col7 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row0_col8 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row1_col0 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row1_col2 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row1_col3 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row1_col4 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row1_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row1_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row1_col7 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row1_col8 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row2_col0 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row2_col1 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row2_col4 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row2_col5 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row2_col6 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row2_col7 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row3_col0 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row3_col1 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row3_col2 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row3_col4 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row3_col5 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row3_col6 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row3_col7 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row3_col8 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row4_col0 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row4_col1 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row4_col2 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row4_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row4_col5 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row4_col6 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row4_col7 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row4_col8 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row5_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row5_col2 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row5_col3 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row5_col4 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row5_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row5_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row5_col8 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row6_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row6_col3 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row6_col4 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a2b1130d_d7d0_11e9_9ecd_10f0057c9f98row6_col5 {
#             background-color:  #6384eb;
#             color:  #000000;

# %%
plt.scatter(df['Insulin'], df['Glucose'])
plt.ylabel('Insulin')
plt.xlabel('Glucose')
# Out:
# Text(0.5, 0, 'Glucose')

# %% [markdown]
# #### Simillarly, imputation of Insulin can be performed using Linear Regression with Glucose as the feature

# %% [markdown]
# # Feature Extraction

# %%
plt.figure(figsize=(20,10))
sns.distplot(df.groupby('Outcome').get_group(1).Age)
sns.distplot(df.groupby('Outcome').get_group(0).Age)

# %%
df['Age_class']=df['Age']/30
df['Age_class']=df['Age'].astype(int)

# %% [markdown]
# #### We can see that there is a age penalty to diabetes for people  whoes age is greater than 30. So in order to quantify this penalty we classify age into two groups ( >=30 and < 30)

# %% [markdown]
# # PCA

# %%
Covariance = df.drop('Outcome', axis=1).cov() 
# Eigen decomposition
eigen_vals, eigen_vecs = np.linalg.eig(Covariance)
total = eigen_vals.sum()
pd.set_option('float_format', '{:f}'.format)
print(eigen_vals*100/total)
x=0
a=[]
for i in eigen_vals*100/total:
    x+=i
    a.append(x)
plt.plot(range(1,10),a)
plt.xlabel('No. of Features')
plt.ylabel('Variance Percentage')
# Out:
# [9.05022750e+01 4.39967938e+00 2.65583952e+00 1.35329406e+00
#  8.34831205e-01 1.70290984e-01 8.30488549e-02 4.12054194e-05
#  6.99762175e-04]
# Text(0, 0.5, 'Variance Percentage')

# %% [markdown]
# #### More than 99 percent of the variance lies within 5 features as given by eigen values of the covariance matrix. Thus we can reduce the dimensionality of the dataset from 9 (8 + new_feature) to 5 using PCA

# %%
features = df.columns[0:8]
pca = PCA(n_components=5)
x=df.loc[:, features].values
x = StandardScaler().fit_transform(x)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents)
df = pd.concat([principalDf, df[['Outcome']]], axis = 1)

# %% [markdown]
# # Model Building

# %%
avg=0
maxx=-1
minn=100
n=100
for _ in range(n):
    train_df, test_df = train_test_split(df)
    X_train = train_df.drop('Outcome', axis=1)
    Y_train = train_df['Outcome']
    X_test = test_df.drop('Outcome', axis=1)
    Y_test = test_df['Outcome']
    logreg = LogisticRegression()
    logreg.fit(X_train, Y_train)
    Y_pred = logreg.predict(X_test)
    count=0
    acc_log = round (logreg.score(X_test, Y_test) * 100, 2)
    if(acc_log>maxx): 
        maxx=acc_log
    if(acc_log<minn):
        minn=acc_log
    avg += acc_log
print('Minimum accuracy over 100 runs: ', minn)
print('Average accuracy over 100 runs: ', avg/n)
print('Maximum accuracy over 100 runs: ', maxx)
# Out:
# Minimum accuracy over 100 runs:  70.31
# Average accuracy over 100 runs:  76.80260000000001
# Maximum accuracy over 100 runs:  84.38

# %% [markdown]
# #### Here we have used Logistic Regression to predict diabetes because we need binary (discreet) output
# #### We are getting average accuracy of 76%
